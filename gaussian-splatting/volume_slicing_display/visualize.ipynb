# %%
import torch
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scene import Scene
from tqdm import tqdm
from os import makedirs
from gaussian_renderer import render
import torchvision
from utils.general_utils import safe_state
from argparse import ArgumentParser
from arguments import ModelParams, PipelineParams, get_combined_args
from gaussian_renderer import GaussianModel
try:
    from diff_gaussian_rasterization import SparseGaussianAdam
    SPARSE_ADAM_AVAILABLE = True
except:
    SPARSE_ADAM_AVAILABLE = False

# %%
from argparse import Namespace
parser = ArgumentParser(description="Testing script parameters")

model = ModelParams(parser, sentinel=True)
pipeline = PipelineParams(parser)

args = Namespace(
    sh_degree = 3,
    model_path="../output/6bd50db1-7",
    source_path="../data/bigfoot",
    images = "images",
    depths = "",
    resolution = -1,
    white_background = False,
    train_test_exp = False,
    data_device = "cuda",
    eval = False,
    debug = False,
    antialiasing = False,
    convert_SHs_python = False,
    compute_cov3D_python = False
)

dataset = model.extract(args)
pipeline = pipeline.extract(args)

gaussians = GaussianModel(dataset.sh_degree)



# Sceneの作成
scene = Scene(dataset, gaussians, load_iteration=-1, shuffle=False)
# Out:
# Loading trained model at iteration 30000
# Reading camera 1/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2582.0138469010963 for both axes.
# Reading camera 2/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2595.9419245632284 for both axes.
# Reading camera 3/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2609.0026778697584 for both axes.
# Reading camera 4/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2626.3193412834958 for both axes.
# Reading camera 5/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2620.1899792579256 for both axes.
# Reading camera 6/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2612.4946906037335 for both axes.
# Reading camera 7/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2613.3063885904285 for both axes.
# Reading camera 8/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2620.1061502307753 for both axes.
# Reading camera 9/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2629.9863410153043 for both axes.
# Reading camera 10/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2618.437671732079 for both axes.
# Reading camera 11/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2622.7088153584673 for both axes.
# Reading camera 12/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2616.70308607459 for both axes.
# Reading camera 13/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2625.3044165603806 for both axes.
# Reading camera 14/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2632.7184294112267 for both axes.
# Reading camera 15/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2640.78196712957 for both axes.
# Reading camera 16/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2650.266179815252 for both axes.
# Reading camera 17/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2648.229695029518 for both axes.
# Reading camera 18/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2640.9850124511654 for both axes.
# Reading camera 19/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2638.2575226934796 for both axes.
# Reading camera 20/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2635.16170578938 for both axes.
# Reading camera 21/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2632.853050780153 for both axes.
# Reading camera 22/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2635.313084009339 for both axes.
# Reading camera 23/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2636.430978090103 for both axes.
# Reading camera 24/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2634.876320832882 for both axes.
# Reading camera 25/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2634.574365293093 for both axes.
# Reading camera 26/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2628.9629624875306 for both axes.
# Reading camera 27/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2618.0537855515313 for both axes.
# Reading camera 28/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2619.049292224528 for both axes.
# Reading camera 29/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2624.650313304004 for both axes.
# Reading camera 30/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2633.115388058128 for both axes.
# Reading camera 31/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2637.168752609894 for both axes.
# Reading camera 32/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2664.768039104676 for both axes.
# Reading camera 33/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2662.9808121311275 for both axes.
# Reading camera 34/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2643.724325721536 for both axes.
# Reading camera 35/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2637.7977120186188 for both axes.
# Reading camera 36/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2628.9282135963776 for both axes.
# Reading camera 37/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2612.753808493343 for both axes.
# Reading camera 38/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2624.9554758904783 for both axes.
# Reading camera 39/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2632.9522494912776 for both axes.
# Reading camera 40/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2648.2457723382845 for both axes.
# Reading camera 41/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2623.0351076958323 for both axes.
# Reading camera 42/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2641.661983126542 for both axes.
# Reading camera 43/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2653.32337206679 for both axes.
# Reading camera 44/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2639.4148409431573 for both axes.
# Reading camera 45/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2638.2502510221434 for both axes.
# Reading camera 46/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2634.128189914436 for both axes.
# Reading camera 47/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2623.087846541915 for both axes.
# Reading camera 48/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2591.5771324255484 for both axes.
# Reading camera 49/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2584.3912222806384 for both axes.
# Reading camera 50/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2569.4440463165033 for both axes.
# Reading camera 51/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2591.278926419992 for both axes.
# Reading camera 52/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2605.3383220850747 for both axes.
# Reading camera 53/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2617.232511483818 for both axes.
# Reading camera 54/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2569.372204054308 for both axes.
# Reading camera 55/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2610.9818138600594 for both axes.
# Reading camera 56/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2638.280092542687 for both axes.
# Reading camera 57/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2617.224353433295 for both axes.
# Reading camera 58/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2608.9670130503823 for both axes.
# Reading camera 59/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2636.049601483633 for both axes.
# Reading camera 60/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2606.0689258632488 for both axes.
# Reading camera 61/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2588.9823305729074 for both axes.
# Reading camera 62/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2592.1580293867564 for both axes.
# Reading camera 63/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2645.0979460813846 for both axes.
# Reading camera 64/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2638.811072522778 for both axes.
# Reading camera 65/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2650.803055486071 for both axes.
# Reading camera 66/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2644.069121455872 for both axes.
# Reading camera 67/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2646.8975578423638 for both axes.
# Reading camera 68/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 2666.380054020016 for both axes.
# Reading camera 69/69Warning: Colmap camera model SIMPLE_RADIAL not handled, using focal length 3368.7516011407424 for both axes.
#
# Loading Training Cameras
# Loading Test Cameras

# %%
from pathlib import Path
ply_file = Path(r"C:\Users\Maemaeko\imari_lab\gaussian-splatting\output\6bd50db1-7\point_cloud\iteration_30000\point_cloud.ply")
scene.gaussians.load_ply(ply_file)
gaussians = scene.gaussians
import matplotlib.pyplot as plt
view = scene.getTrainCameras()[36]
print(view.image_name)
print(view.FoVx, view.FoVy)
print(view.colmap_id)
bg_color = [1,1,1] if dataset.white_background else [0, 0, 0]
background = torch.tensor(bg_color, dtype=torch.float32, device="cuda")
rendering = render(view, gaussians, pipeline, background, use_trained_exp=dataset.train_test_exp, separate_sh=SPARSE_ADAM_AVAILABLE)["render"]

# レンダリングの可視化
rendering = rendering.permute(1, 2, 0).detach().cpu().numpy()

plt.imshow(rendering)
plt.axis('off')  # 軸を非表示にする
# Out:
# 3_0181.png
# 0.704232208709321 0.4076177113708152
# 87
# (-0.5, 1599.5, 899.5, -0.5)

# %%
# gaussians_copyのxyzに関してヒストグラム
import matplotlib.pyplot as plt
xyz = gaussians.get_xyz.detach().cpu().numpy()

plt.figure(figsize=(15, 5))

# X軸のヒストグラム
plt.subplot(1, 3, 1)
plt.hist(xyz[:, 0], bins=50, alpha=0.7, color='red', density=True)
plt.title('X-axis Distribution')
plt.xlabel('X coordinate')
plt.ylabel('Density')

# Y軸のヒストグラム
plt.subplot(1, 3, 2)
plt.hist(xyz[:, 1], bins=50, alpha=0.7, color='green', density=True)
plt.title('Y-axis Distribution')
plt.xlabel('Y coordinate')
plt.ylabel('Density')

# Z軸のヒストグラム
plt.subplot(1, 3, 3)
plt.hist(xyz[:, 2], bins=50, alpha=0.7, color='blue', density=True)
plt.title('Z-axis Distribution')
plt.xlabel('Z coordinate')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# 統計情報も表示
print("XYZ Statistics:")
print(f"X: min={xyz[:, 0].min():.3f}, max={xyz[:, 0].max():.3f}, mean={xyz[:, 0].mean():.3f}, std={xyz[:, 0].std():.3f}")
print(f"Y: min={xyz[:, 1].min():.3f}, max={xyz[:, 1].max():.3f}, mean={xyz[:, 1].mean():.3f}, std={xyz[:, 1].std():.3f}")
print(f"Z: min={xyz[:, 2].min():.3f}, max={xyz[:, 2].max():.3f}, mean={xyz[:, 2].mean():.3f}, std={xyz[:, 2].std():.3f}")
# Out:
# XYZ Statistics:
# X: min=-4.159, max=4.241, mean=-0.392, std=0.362
# Y: min=-4.220, max=1.858, mean=-2.071, std=0.328
# Z: min=-1.534, max=3.966, mean=1.870, std=0.257

# %%
#import add_pypath
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), 'gaussian-splatting-lightning')))
import torch
import numpy as np
from internal.utils import gaussian_utils
import copy
from viser import transforms as vt
import math

xyz = gaussians.get_xyz
scaling = gaussians.get_scaling

rotation = gaussians.get_rotation

features_dc = gaussians.get_features_dc
features_rest = gaussians.get_features_rest

features = torch.cat([features_dc, features_rest], dim=-2)

class RotationUtils:
    @staticmethod
    def rx(theta):
        return np.matrix([[1, 0, 0],
                          [0, np.cos(theta), -np.sin(theta)],
                          [0, np.sin(theta), np.cos(theta)]])

    @staticmethod
    def ry(theta):
        return np.matrix([[np.cos(theta), 0, np.sin(theta)],
                          [0, 1, 0],
                          [-np.sin(theta), 0, np.cos(theta)]])

    @staticmethod
    def rz(theta):
        return np.matrix([[np.cos(theta), -np.sin(theta), 0],
                          [np.sin(theta), np.cos(theta), 0],
                          [0, 0, 1]])



# translate
#t_xyz = np.array([3.497, -0.494, 3.45])  # Translation vector
t_xyz = np.array([1.511, -0.373, 1.555], dtype=np.float32)  # Translation vector
#t_xyz = np.array([0, 0, 0])  # Translation vector
xyz = gaussian_utils.GaussianTransformUtils.translation(xyz, *t_xyz.tolist())

# rotate
rx, ry, rz = math.radians(92.37), math.radians(1.67), math.radians(-72.81)
#rx, ry, rz = 0, 0, 0
rot_mat = RotationUtils.rx(rx) @ RotationUtils.ry(ry) @ RotationUtils.rz(rz)
r_wxyz = vt.SO3.from_matrix(rot_mat).wxyz

xyz, rotation, new_features = gaussian_utils.GaussianTransformUtils.rotate_by_wxyz_quaternions(
            xyz=xyz,
            rotations=rotation,
            features=features,
            quaternions=torch.tensor(r_wxyz).to(xyz),
        )

# rescale
xyz, scaling = gaussian_utils.GaussianTransformUtils.rescale(
            xyz,
            scaling,
            1.7
        )



gaussians_copy = copy.deepcopy(gaussians)
gaussians_copy._xyz = xyz
gaussians_copy._scaling = torch.log(scaling)

rendering = render(view, gaussians_copy, pipeline, background, use_trained_exp=dataset.train_test_exp, separate_sh=SPARSE_ADAM_AVAILABLE)["render"]

# レンダリングの可視化
rendering = rendering.permute(1, 2, 0).detach().cpu().numpy()

plt.imshow(rendering)
plt.axis('off')  # 軸を非表示にする
# Out:
# c:\Users\Maemaeko\anaconda3\envs\gaussian_splatting_windows\lib\site-packages\e3nn\o3\_wigner.py:97: UserWarning: An output with one or more elements was resized since it had shape [1, 3, 3], which does not match the required output shape [1, 1, 3, 3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\Resize.cpp:24.)
#   return torch.matrix_exp(alpha * X[1]) @ torch.matrix_exp(beta * X[0]) @ torch.matrix_exp(gamma * X[1])
# (-0.5, 1599.5, 899.5, -0.5)

# %%
# gaussians_copyのxyzに関してヒストグラム
import matplotlib.pyplot as plt
xyz = gaussians_copy.get_xyz.detach().cpu().numpy()

plt.figure(figsize=(15, 5))

# X軸のヒストグラム
plt.subplot(1, 3, 1)
plt.hist(xyz[:, 0], bins=50, alpha=0.7, color='red', density=True)
plt.title('X-axis Distribution')
plt.xlabel('X coordinate')
plt.ylabel('Density')

# Y軸のヒストグラム
plt.subplot(1, 3, 2)
plt.hist(xyz[:, 1], bins=50, alpha=0.7, color='green', density=True)
plt.title('Y-axis Distribution')
plt.xlabel('Y coordinate')
plt.ylabel('Density')

# Z軸のヒストグラム
plt.subplot(1, 3, 3)
plt.hist(xyz[:, 2], bins=50, alpha=0.7, color='blue', density=True)
plt.title('Z-axis Distribution')
plt.xlabel('Z coordinate')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# 統計情報も表示
print("XYZ Statistics:")
print(f"X: min={xyz[:, 0].min():.3f}, max={xyz[:, 0].max():.3f}, mean={xyz[:, 0].mean():.3f}, std={xyz[:, 0].std():.3f}")
print(f"Y: min={xyz[:, 1].min():.3f}, max={xyz[:, 1].max():.3f}, mean={xyz[:, 1].mean():.3f}, std={xyz[:, 1].std():.3f}")
print(f"Z: min={xyz[:, 2].min():.3f}, max={xyz[:, 2].max():.3f}, mean={xyz[:, 2].mean():.3f}, std={xyz[:, 2].std():.3f}")
# XYZ Statistics:
# X: min=-4.159, max=4.241, mean=-0.392, std=0.362
# Y: min=-4.220, max=1.858, mean=-2.071, std=0.328
# Z: min=-1.534, max=3.966, mean=1.870, std=0.257
# Out:
# XYZ Statistics:
# X: min=-6.204, max=4.390, mean=-3.235, std=0.582
# Y: min=-9.393, max=0.314, mean=-5.788, std=0.422
# Z: min=-11.646, max=3.383, mean=-3.287, std=0.603

# %%
# output gaussians
from pathlib import Path
output_path = Path(r"C:\Users\Maemaeko\imari_lab\gaussian-splatting\output\6bd50db1-7\point_cloud\iteration_30000\output_cloud.ply")
gaussians_copy.save_ply(output_path)

# %%
from scene.cameras import Camera
from PIL import Image

views = scene.getTrainCameras()
view = views[36]
print(view.image_name)
print(view.R)
print(view.T)
import numpy as np
w2c = np.eye(4, dtype=view.R.dtype)
w2c[:3, :3] = view.R
w2c[:3, 3] = view.T

import numpy as np, math

# 1) 平行移動
#t =  np.array([0, 0, 0]) 
#t = np.array([3.497, -0.494, 3.45])  # Translation vector
#t = np.array([0, 0, 0], dtype=np.float32)  # 例としてゼロ平行移動を使用
t = np.array([1.359, -2.2241, 1.897], dtype=np.float32)  # Translation vector
T = np.eye(4, dtype=np.float32)
T[:3, 3] = t

# 2) 回転（既に rot_mat が 3x3 で得られている想定）
#    RotationUtils.rx/ry/rz が numpy array を返すならそのまま使えます
rx, ry, rz = math.radians(-88.58), math.radians(1.42), math.radians(93.38)
#rx, ry, rz = 0, 0, 0  # 例としてゼロ回転を使用
rot_mat = RotationUtils.rx(rx) @ RotationUtils.ry(ry) @ RotationUtils.rz(rz)
R3 = RotationUtils.rx(rx) @ RotationUtils.ry(ry) @ RotationUtils.rz(rz)
R = np.eye(4, dtype=np.float32)
R[:3, :3] = R3

# 3) スケール
s = 1
S = np.eye(4, dtype=np.float32)
S[0,0] = S[1,1] = S[2,2] = s


S_inv = np.linalg.inv(S)
R_inv = np.linalg.inv(R)
T_inv = np.linalg.inv(T)

# オブジェクト変換行列を合成
M_obj = S @ R @ T   # （注：適用順序は「平行移動→回転→スケール」に対応）

# M_objの逆行列を計算
M_obj_inv = np.linalg.inv(M_obj)

# w2cに M_obj_inv を適用
w2c = w2c @ M_obj_inv

new_r = w2c[:3, :3]
#print("new_r", new_r)
new_t = w2c[:3, 3]
#print("new_t", new_t)

 

view = Camera(
        colmap_id=87,
        R = view.R,
        T = view.T,
        FoVx=0.704232208709321,
        FoVy=0.4076177113708152,
        image_name="none",
        uid=15,
        resolution=(1600, 900),
        depth_params = None,
        image=Image.new('RGB', (1600, 900), (0, 0, 0)),
        invdepthmap=None,
        trans=t,  # 平行移動
        scale=1,
        rotate= rot_mat
    )
print(view.world_view_transform)


rendering = render(view, gaussians_copy, pipeline, background, use_trained_exp=dataset.train_test_exp, separate_sh=SPARSE_ADAM_AVAILABLE)["render"]

# レンダリングの可視化
rendering = rendering.permute(1, 2, 0).detach().cpu().numpy()

plt.imshow(rendering)
plt.axis('off')  # 軸を非表示にする
# Out:
# 3_0181.png
# [[-0.98992062  0.10534552  0.0946546 ]
#  [-0.08064862  0.13008268 -0.98821774]
#  [-0.11641723 -0.98589088 -0.12027555]]
# [-0.28322088  2.4635013   3.19446734]
# tensor([[ 0.1359, -0.1605,  0.9776,  0.0000],
#         [-0.1442, -0.9795, -0.1407,  0.0000],
#         [ 0.9802, -0.1218, -0.1563,  0.0000],
#         [ 1.1036,  4.4799,  1.0961,  1.0000]], device='cuda:0')
# (-0.5, 1599.5, 899.5, -0.5)

# %%
from scene.cameras import Camera
from PIL import Image

views = scene.getTrainCameras()
view = views[36]
print(view.image_name)
print(view.R)
print(view.T)
import numpy as np
w2c = np.eye(4, dtype=view.R.dtype)
w2c[:3, :3] = view.R
w2c[:3, 3] = view.T

import numpy as np, math

# 1) 平行移動
t =  np.array([0, 0, 0]) 
#t = np.array([3.497, -0.494, 3.45])  # Translation vector
#t = np.array([0, 0, 0], dtype=np.float32)  # 例としてゼロ平行移動を使用
T = np.eye(4, dtype=np.float32)
T[:3, 3] = t

# 2) 回転（既に rot_mat が 3x3 で得られている想定）
#    RotationUtils.rx/ry/rz が numpy array を返すならそのまま使えます
rx, ry, rz = math.radians(-88.58), math.radians(1.42), math.radians(93.38)
#rx, ry, rz = 0, 0, 0  # 例としてゼロ回転を使用
rot_mat = RotationUtils.rx(rx) @ RotationUtils.ry(ry) @ RotationUtils.rz(rz)
R3 = RotationUtils.rx(rx) @ RotationUtils.ry(ry) @ RotationUtils.rz(rz)
R = np.eye(4, dtype=np.float32)
R[:3, :3] = R3

# 3) スケール
s = 1
S = np.eye(4, dtype=np.float32)
S[0,0] = S[1,1] = S[2,2] = s


S_inv = np.linalg.inv(S)
R_inv = np.linalg.inv(R)
T_inv = np.linalg.inv(T)

# オブジェクト変換行列を合成
M_obj = S @ R @ T   # （注：適用順序は「平行移動→回転→スケール」に対応）

# M_objの逆行列を計算
M_obj_inv = np.linalg.inv(M_obj)

# w2cに M_obj_inv を適用
w2c = w2c @ M_obj_inv

new_r = w2c[:3, :3]
#print("new_r", new_r)
new_t = w2c[:3, 3]
#print("new_t", new_t)

 

view = Camera(
        colmap_id=87,
        R = np.array([[0.1359, -0.1605,  0.9776],
                      [-0.1442, -0.9795, -0.1407],
                      [ 0.9802, -0.1218, -0.1563]]),
        #R = view.R,
        T = np.array([3.5403,  5.5607,  2.7902]),
        #T = view.T,
        FoVx=0.5565993180102227,
        FoVy=0.5565993180102227,
        image_name="none",
        uid=15,
        resolution=(512, 512),
        depth_params = None,
        image=Image.new('RGB', (512, 512), (0, 0, 0)),
        invdepthmap=None,
        # trans=t,  # 平行移動
        # scale=1,
        # rotate= rot_mat
    )
print(view.world_view_transform)


rendering = render(view, gaussians_copy, pipeline, background, use_trained_exp=dataset.train_test_exp, separate_sh=SPARSE_ADAM_AVAILABLE)["render"]

# レンダリングの可視化
rendering = rendering.permute(1, 2, 0).detach().cpu().numpy()

plt.imshow(rendering)
plt.axis('off')  # 軸を非表示にする
# Out:
# 3_0181.png
# [[-0.98992062  0.10534552  0.0946546 ]
#  [-0.08064862  0.13008268 -0.98821774]
#  [-0.11641723 -0.98589088 -0.12027555]]
# [-0.28322088  2.4635013   3.19446734]
# tensor([[ 0.1359, -0.1605,  0.9776,  0.0000],
#         [-0.1442, -0.9795, -0.1407,  0.0000],
#         [ 0.9802, -0.1218, -0.1563,  0.0000],
#         [ 3.5403,  5.5607,  2.7902,  1.0000]], device='cuda:0')
# (-0.5, 511.5, 511.5, -0.5)

# %%
import numpy as np
from scene.cameras import Camera


def spherical_to_cartesian(theta, phi, radius):
    x  = radius * np.sin(theta) * np.cos(phi)
    y = radius * np.sin(theta) * np.sin(phi)
    z = radius * np.cos(theta)
    return np.array([x, y, z])

def look_at_transform(
        center,
        lookat,
        up,
    ):
    z = lookat - center

    z = z / np.linalg.norm(z)

    x = np.cross(up, z)
    if np.all(x == 0):
        x = np.cross(up, z + np.array([1e-6, 1e-6, 1e-6]))  # Avoid zero vector
    x = x / np.linalg.norm(x)

    y = np.cross(z, x)
    R = np.stack([x, y, z], axis=1)
    t = -R.T @ center
    view_matrix = np.eye(4)
    view_matrix[:3, :3] = R
    view_matrix[:3, 3] = t
    return view_matrix

def view_matrix_from_spherical(
        theta,
        phi,
        radius,
        lookat = np.array([0, 0, 0]),
        up = np.array([0, 0, 1])
    ):
    center = spherical_to_cartesian(theta, phi, radius)
    return look_at_transform(center, lookat, up)

def get_camera(theta, phi, radius, up=np.array([0, 0, 1])):
    theta = np.array(theta)
    phi = np.array(phi)
    w2c = view_matrix_from_spherical(theta, phi, radius, up=up)
    _r = w2c[:3, :3]
    _t = w2c[:3, 3]

    return Camera(
        colmap_id=65,
        R = _r,
        T = _t, 
        FoVx=0.7119294220716936,
        FoVy=0.4123349887767067,
        image_name="none",
        uid=15,
        resolution=(512, 512),
        depth_params = None,
        image=Image.new('RGB', (512, 512), (0, 0, 0)),
        invdepthmap=None
    )

# %%
import numpy as np
import matplotlib.pyplot as plt

# w2c の R
R_w2c = np.array([
    [-0.,  1.,  0.],
    [ 1.,  0.,  0.],
    [ 0.,  0., -1.]
])

# カメラ座標系の軸方向をワールド座標で求める (R_c2w = R_w2c.T)
R_c2w = R_w2c.T

# 原点（カメラ位置）から各軸の方向ベクトル（長さ1）
origin = np.array([0, 0, 0.3])  # カメラの位置
x_axis = R_c2w[:, 0]  # カメラX軸（赤）
y_axis = R_c2w[:, 1]  # カメラY軸（緑）
z_axis = R_c2w[:, 2]  # カメラZ軸（青）

# 描画
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# カメラ軸
ax.quiver(*origin, *x_axis, color='r', label='Camera X')
ax.quiver(*origin, *y_axis, color='g', label='Camera Y')
ax.quiver(*origin, *z_axis, color='b', label='Camera Z')

# ワールド軸（比較用）
ax.quiver(*origin, 1, 0, 0, color='r', alpha=0.3, linestyle='dashed')
ax.quiver(*origin, 0, 1, 0, color='g', alpha=0.3, linestyle='dashed')
ax.quiver(*origin, 0, 0, 1, color='b', alpha=0.3, linestyle='dashed')

# 軸範囲
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

ax.set_xlabel('World X')
ax.set_ylabel('World Y')
ax.set_zlabel('World Z')
ax.legend()
ax.set_box_aspect([1,1,1])
plt.show()

# %%
view = get_camera(0, 0, 4, up=np.array([1, 0, 0]))

rendering = render(view, gaussians_copy, pipeline, background, use_trained_exp=dataset.train_test_exp, separate_sh=SPARSE_ADAM_AVAILABLE)["render"]

# レンダリングの可視化
rendering = rendering.permute(1, 2, 0).detach().cpu().numpy()

plt.imshow(rendering)
plt.axis('off')  # 軸を非表示にする
